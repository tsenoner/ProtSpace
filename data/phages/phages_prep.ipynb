# %%
import pandas as pd
from pathlib import Path

def process_files_pandas(input_path):
    output_csv = input_path.parent / f"{input_path.stem}_with_ids.csv"
    output_fasta = input_path.with_suffix(".fasta")

    # Read CSV and add identifiers
    df = pd.read_csv(input_path)
    df.insert(0, 'identifier', [f"phage_{i:04d}" for i in range(1, len(df) + 1)])

    # Create FASTA
    with open(output_fasta, 'w') as f:
        for _, row in df.iterrows():
            f.write(f">{row['identifier']}\n{row['sequence']}\n")

    # Remove sequence column and save CSV
    df_clean = df.drop('sequence', axis=1)
    df_clean.to_csv(output_csv, index=False)

# Choose which version to run
csv_path = Path("raw/all_members_7k_function_500_hyp.csv")
csv_path = Path("raw/foldseek_clusterreps_7k_function_500_hyp.csv")
process_files_pandas(csv_path)

# %%
import pandas as pd

df = pd.read_csv("processed/foldseek.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   identifier  7500 non-null   object
#  1   phrog       7500 non-null   int64
#  2   product     7002 non-null   object
#  3   function    7500 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 234.5+ KB

# %%
df['product'].unique()
# Out:
# array(['head-tail adaptor', 'FmdB-like transcriptional regulator',
#        'Rz-like spanin', 'minor head protein', 'HNH endonuclease',
#        'major tail protein', nan, 'DNA binding protein',
#        'tail length tape measure protein', 'DNA polymerase',
#        'tail fiber protein', 'transcriptional repressor',
#        'replication initiation protein', 'homing endonuclease', 'holin',
#        'polymerase', 'major head protein', 'integrase',
#        'DNA methyltransferase', 'aminotransferase', 'endolysin',
#        'RecT-like ssDNA annealing protein',
#        'anaerobic ribonucleoside reductase large subunit',
#        'phosphoheptose isomerase', 'minor tail protein', 'tail protein',
#        'virion structural protein', 'Tail assembly chaperone',
#        'tail collar fiber protein', 'terminase small subunit',
#        'RNA replicase beta subunit', 'tail completion or Neck1 protein',
#        'head closure Hc1', 'sigma factor', '2OG-Fe(II) oxygenase',
#        'Arc-like repressor', 'ADP-ribosyltransferase exoenzyme toxin',
#        'HTH DNA binding protein', 'head-tail adaptor Ad2',
#        'portal protein', 'tail spike protein',
#        'baseplate wedge tail fiber protein connector',
#        'Sak4-like ssDNA annealing protein', 'baseplate assembly protein',
#        'tail needle protein', 'RNA polymerase sigma factor',
#        'head maturation protease', 'anti-repressor Ant',
#        'superoxide dismutase precursor', 'virion RNA polymerase',
#        'head scaffolding protein', 'membrane protein',
#        'glycosyltransferase', 'transcriptional regulator',
#        'tail terminator', 'pilot protein for DNA ejection', 'tail tube',
#        'neck protein', 'MarR family transcrition regulator',
#        'ribonucleotide reductase', 'Mu Gam-like end protection',
#        'methyltransferase', 'long tail fiber protein distal subunit',
#        'structural protein', 'translational regulator',
#        'tail assembly chaperone', 'DNA primase/helicase', 'head protein',
#        'CRISPR/Cas system associated',
#        'ribonucleoside-diphosphate reductase large subunit',
#        'WhiB transcriptional factor', 'esterase/lipase',
#        'head morphogenesis', 'ATP-dependent DNA ligase', 'exonuclease',
#        'ParB C-terminal domain', 'endonuclease',
#        'late transcriptional activator', 'DarB-like antirestriction',
#        'internal virion protein', 'cytidyltransferase',
#        'tail tube protein', 'minor coat protein',
#        'RuvC-like Holliday junction resolvase', 'DNA helicase',
#        'QueE-like  radical SAM domain', 'phosphofructokinase',
#        'dCMP deaminase', 'Lar-like restriction alleviation protein',
#        'protease', 'CI-like repressor', 'toxin',
#        'tail protein with lysin activity', 'NAD synthetase',
#        'nucleotide kinase', 'regulator of chromosome condensation',
#        'ribonucleoside diphosphate reductase small subunit',
#        'galactosyl transferase', 'tyrosyl-tRNA synthetase', 'transposase',
#        'tail sheath', 'Srd anti-sigma factor', 'baseplate wedge subunit',
#        'terminase large subunit', 'co-chaperonin GroES',
#        'endonuclease VII', 'Alt-like transcription activator',
#        'FtsK/SpoIIIE-like protein', 'amidoligase enzyme',
#        'hol-like chemotaxis', 'exonuclease V',
#        'ocr-like anti-restriction', 'baseplate spike',
#        'gamma-glutamyl cyclotransferase',
#        'ribosomal protein S6 glutaminyl transferase',
#        'DNA polymerase exonuclease subunit', 'DNA ejection protein',
#        'Reverse transcriptase', 'HTH DNA binding domain protein',
#        'metallo-phosphoesterase', 'tail fiber protein/ lysozyme',
#        'excisionase and transcriptional regulator',
#        'UvsY-like recombination mediator', 'short tail fiber protein',
#        'baseplate protein', 'MazG-like pyrophosphatase',
#        'UvsX-like recombinase', 'ABC transporter', 'peptidase',
#        'DNA ejection', 'glucosyltransferase', 'acetyltransferase',
#        'baseplate hub', 'NinB/ Orf homologous recombination mediator',
#        'transglycosylase', 'DNA endonuclease V', 'Rnase E',
#        'baseplate hub subunit and tail lysozyme',
#        'RinB-like transcriptional activator', 'tRNA methyltransferase',
#        'tail fiber protein and host specificity',
#        'transcriptional regulator, D5-like', 'central tail fiber J',
#        'DnaD-like helicase loader',
#        'NinG/ Rap DNA junction specific endonuclease',
#        'MutT/NUDIX hydrolase', 'Holliday junction resolvase',
#        'head decoration', 'minor head protein Ace-like',
#        'cation efflux protein', 'hemolysin',
#        'clamp loader of DNA polymerase', 'distal tail protein Dit',
#        'NrdD-like anaerobic ribonucleotide reductase large subunit',
#        'RF-1 domain peptide chain release factor', 'DNA primase',
#        'Dda-like helicase', 'amidase',
#        'DNA polymerase processivity factor',
#        'beta-propeller repeat protein', 'lipoprotein', 'hydrolase',
#        'DNA polymerase/primase', 'RusA-like Holliday junction resolvase',
#        'ParB-like partition protein',
#        'SbcC-like subunit of palindrome specific endonuclease', 'ATPase',
#        'CII-like transcriptional activator', 'guanylate kinase',
#        'dUTPase', 'tail fiber assembly', 'thymidylate synthase',
#        'DNA transposition protein', 'translation elongation factor',
#        'periplasmic protein', 'DnaC-like helicase loader',
#        'dihydrofolate reductase',
#        'protein kinase; inhibitor of host transcription; positively regulates RNaseIII; negatively on RNaseE',
#        'single strand DNA binding protein',
#        'plasmid antitoxin with HTH domain', 'RNA polymerase beta subunit',
#        'tail fiber protein; host specificity',
#        'transcription antiterminator', 'collagen like minor tail',
#        'radical SAM domain-containing protein',
#        'PhoH-like phosphate starvation-inducible', 'tail chaperonin',
#        'released from the phage upon host infection',
#        'tail assembly protein', 'nuclease', 'head closure Hc3',
#        'antitoxin from a toxin-antitoxin system',
#        'baseplate hub assembly catalyst',
#        'internal virion protein with endolysin domain',
#        'Mrh transcription modulator under heat shock', 'holin/anti-holin',
#        'RNA ligase', 'distal tail protein', 'head closure Hc2',
#        'replication initiation O-like', 'excisionase', 'DNA ligase',
#        'DNA repair protein', 'nucleotidyltransferase',
#        'Gp2.5-like ssDNA binding protein and ssDNA annealing protein',
#        'nucleotide-sugar epimerase', 'head-tail adaptor Ad1',
#        'late sigma transcription factor',
#        'queuine tRNA-ribosyltransferase', 'head assembly',
#        'porphyrin biosynthesis', 'pentameric base spike protein',
#        'RecJ-like ssDNA exonuclease', 'peptidase HslV family', 'kinase',
#        'Mom-like DNA modification protein', 'Zot-like toxin',
#        'late promoter transcriptional regulator', 'lytic tail protein',
#        'head-tail connector protein', 'thymidylate kinase', 'helicase',
#        'transmembrane protein', 'prohead protease inhibitor',
#        'flavodoxin', 'cAMP-dependent Kef-type K+ transporter',
#        'terminase',
#        'bifunctional heptose 7-phosphate kinase/heptose 1-phosphate adenyltransferase',
#        'head closure', 'primosomal protein',
#        'photosystem I psaA/psaB protein', 'prohead',
#        'Panton-Valentine leukocicin',
#        'L-shaped tail fiber protein assembly', 'tail sheath stabilizer',
#        'site-specific recombination directionality factor RDF',
#        'Abi alpha-like abortive infection mechanism',
#        'FabG-like 3-oxoacyl-(acyl-carrier-protein) reductase',
#        'Hsp20 heat shock protein',
#        'anaerobic ribonucleotide reductase small subunit',
#        'Cas4-domain exonuclease', 'phosphoribosyl transferase',
#        'cysteine dioxygenase',
#        'nucleoside triphosphate pyrophosphohydrolase',
#        'antimicrobial peptide resistance and lipid A acylation protein PagP',
#        'ParA-like partition protein', 'nitroreductase',
#        'partition protein', 'homing endonuclease with LAGLIDADG motif',
#        'acyl-CoA N-acyltransferase', 'nucleoside deoxyribosyltransferase',
#        'tail protein with endopeptidase domain', 'DNA invertase',
#        'anti-termination protein Q-like', 'baseplate wedge initiator',
#        'polynucleotide kinase',
#        'enoyl-CoA hydratase/carnithine racemase-like',
#        'PAAR motif of membran proteins', 'DnaB-like replicative helicase',
#        'structural protein with Ig domain',
#        'beta-glucosyl-HMC-alpha-glucosyltransferase',
#        'host nuclease inhibitor', 'helicase loader',
#        'alpha-2;3-sialyltransferase', 'sporulation protein',
#        'nucleoside 2-deoxyribosyltransferase',
#        'replisome organizer DnaA-like', 'recombinase',
#        'UDP-glucose dehydrogenase', 'GtrB-like O-antigen conversion',
#        'beta-1,4-glycosyltransferase', "5'-3' deoxyribonucleotidase",
#        'Alt-like RNA polymerase ADP-ribosyltransferase',
#        'GtrC-like O-antigen conversion translocase', 'Avd protein of DGR',
#        'high light inducible protein', 'RIIA lysis inhibitor',
#        'DksA-like zinc-finger protein', 'acetyl-CoA acetyltransferase',
#        'anti-repressor', 'CII-like regulator', 'methylamine utilization',
#        'Holliday junction branch migration helicase',
#        'toxin-antitoxin system HicB-like', 'pyrophosphatase',
#        'dCTP deaminase', 'transcriptional activator',
#        'transcriptional regulator WhiB-like', 'peptide deformylase',
#        'gpCom control of modification', 'hyaluronidase',
#        'GTP-binding domain', 'major tail protein with Ig-like domain',
#        'SbcD-like subunit of palindrome specific endonuclease',
#        'L-glutamine-D-fructose-6-phosphate aminotransferase',
#        'immunity to superinfection', 'tRNA splicing ligase',
#        'DNA circularization', 'NAD-dependent DNA ligase',
#        'plasmid stability', 'anti-restriction protein',
#        'tRNA nucleotidyltransferase', 'GtrA-like O-antigen conversion',
#        'Cox-like excisionase and repressor', 'metallo-protease',
#        'Ren-like exclusion protein', 'ATP-dependent protease', 'primase',
#        'DNA repair exonuclease', 'nucleotide pyrophosphohydrolase',
#        'starvation-inducible transcriptional regulator',
#        'replication protein', 'host RecBCD nuclease inhibitor',
#        'RNA ligase and tail fiber protein attachment catalyst',
#        'head decoration protein', 'tRNA amidotransferase',
#        'endolysin; inhibits RNA polymerase', 'restriction endonuclease',
#        'involved in bacteriocin production or immunity',
#        'nicking at origin of replication', "RNA 2'-phosphotransferase",
#        'Erf-like ssDNA annealing protein', 'serine-threonine kinase',
#        'RecA or Sak4, length ?', 'baseplate tail tube cap',
#        'ribonucleotide reductase large subunit', 'metallo-endopeptidase',
#        'Hoc-like head decoration', 'CsrA-like regulator', 'esterase',
#        'nicotinamide phosphoribosyl transferase',
#        'zinc-finger domain protein',
#        'DnaA-like replication initiation protein',
#        'partition protein ATPase', 'head-tail joining',
#        'Ku-like DNA end binding', 'ribose-phosphate pyrophosphokinase',
#        'DNA helicase loader', 'ferrochelatase',
#        'cyanobacterial phosphoribosylglycinamide formyltransferase',
#        'head-tail adaptor Ad3', 'signal peptide motif',
#        'phosphohydrolase', 'nudix hydrolase',
#        'baseplate hub and tail lysozyme',
#        'TciB-like inhibition of cell division or resistance to colicin',
#        'minor head protein and DNA pilot', 'adaptor Ad4',
#        'exonuclease VIII', 'lipoprotein precursor',
#        'DNA transfer protein', 'Bet-like ssDNA annealing protein',
#        'major coat protein',
#        'Kil protein for bacterial septation inhibition',
#        'ribonucleoside-diphosphate reductase beta subunit',
#        'unknown function', 'dATP / dGTP pyrophosphohydrolase',
#        'thioredoxin domain', 'acyl carrier protein',
#        'tail associated lysin', 'deoxynucleoside monophosphate kinase',
#        'MokW-like host killing', 'tubulin PhuZ', 'DNA polymerase I',
#        'major spike protein',
#        'glycerophosphoryl diester phosphodiesterase',
#        'pectin lyase activity', 'lytic tail fiber protein',
#        'CpeT-like antenna protein', 'DNA polymerase III theta subunit',
#        'base plate tail tube protein',
#        'rolling circle DNA replication initiation',
#        'dATP triphosphohydrolase', 'ferredoxin', 'tail completion',
#        'PnuC-like nicotinamide mononucleotide transport',
#        'tail spike protein with colonic acid degradation activity',
#        'transcription factor', 'phosphodiesterase',
#        'phosphate transporter subunit', 'Galactose-3-O-sulfotransferase',
#        'RNA-binding protein', 'phosphoadenosine phosphosulfate reductase',
#        'alkylated DNA repair', 'host range and adsorption protein',
#        'Fe-S oxidoreductase', 'radical SAM domain protein',
#        'DNA topoisomerase', 'DHH phosphoesterase',
#        'protein with Ig domain',
#        'QueD-like  6-pyruvoyl-tetrahydropterin synthase',
#        'S-adenosylmethionine decarboxylase',
#        'tail protein and host specificity', 'pre-neck appendage protein',
#        'polysaccharide deacetylase', 'transfer protein',
#        'metal-dependent hydrolase', 'cold shock protein',
#        'glycoside hydrolase', 'Gp5.5-like host HNS inhibition',
#        'zinc containing alcohol dehydrogenase superfamily',
#        'nuclear shell protein', 'DNA condensation',
#        'MazF-like growth inhibitor', 'DNA topoisomerase II', 'lipase',
#        'head fiber protein', 'replication', 'nucleoid associated protein',
#        'RNA polymerase', 'MerR-like transcriptional regulator',
#        'phosphoribosylaminoimidazole synthetase',
#        'tail injection transglycosylase',
#        'sulfatase-modifying factor enzyme', 'secreted protein',
#        'outer membrane protein', 'tail chaperone protein',
#        'Sak-like ssDNA annealing protein', 'tail fiber assembly protein',
#        'RecE-like recombination exonuclease',
#        'DprA-like DNA recombination-mediator protein',
#        'ParB-like partition nuclease', 'HAD-superfamily hydrolase',
#        'QueC-like queuosine biosynthesis', 'DNA repair photolyase',
#        'O-acetyltransferase', 'Nol-like carbamoyltransferase',
#        'UmuD-like protein', 'Erf recombination cofactor Arf',
#        'tail appendage', 'assembly (protein IV of M13)',
#        'DNA end protector', 'tail needle knob', 'tail collar protein',
#        'GtrB glycosyltransferase for O-antigen conversion',
#        'replisome organizer', 'lysophospholipase L1-like esterase',
#        'ribosome associated inhibitor A; zinc finger domain',
#        'CopG-like transcriptional repressor',
#        'neck passage structure protein',
#        'hinge connector of long tail fiber protein distal connector',
#        'lower collar', 'tRNA splicing ligase RtcB',
#        'metal-dependent phosphohydrolase', 'glutamine amidotransferase',
#        'Rnase H', 'dsDNA binding protein', 'Doc-like toxin',
#        'HicB-like antitoxin', 'tail fiber protein proximal subunit',
#        'GTP cyclohydrolase', 'nucloid associated Lsr2-like',
#        'major head and protease protein', 'cell division inhibitor',
#        'PetE plastocyanine', 'Rha-like transcriptional regulator',
#        'tellurite resistance', 'phosphoesterase'], dtype=object)

# %% [markdown]
# ### Classification system for "product"

# %%
import pandas as pd
import numpy as np
import re

def create_phage_protein_mapping():
    """
    Creates a dictionary mapping specific phage proteins to broader functional categories.
    """
    return {
        # Structural proteins
        'major_capsid': [
            r'major head protein',
            r'major coat protein',
            r'head protein',
            r'major head and protease protein',
            r'head morphogenesis',
            r'head decoration',
            r'head closure',
            r'head assembly',
            r'head fiber protein',
            r'minor head protein',
            r'internal head protein'
        ],
        'tail_proteins': [
            r'tail protein',
            r'major tail protein',
            r'minor tail protein',
            r'tail fiber protein',
            r'tail assembly',
            r'tail sheath',
            r'tail tube',
            r'tail spike protein',
            r'tail completion',
            r'tail collar',
            r'tail terminator',
            r'tail length tape measure protein',
            r'tail associated',
            r'tail tip',
            r'tail chaperone',
            r'tail assembly chaperone'
        ],
        'baseplate': [
            r'baseplate',
            r'base plate'
        ],
        'portal_connector': [
            r'portal protein',
            r'head-tail connector',
            r'head-tail adaptor',
            r'head-tail joining'
        ],

        # DNA/RNA processing
        'dna_replication': [
            r'dna polymerase',
            r'dna helicase',
            r'dna primase',
            r'replication',
            r'replicative',
            r'single strand.*binding',
            r'ssb',
            r'clamp loader'
        ],
        'dna_packaging': [
            r'terminase',
            r'packaging'
        ],
        'transcription': [
            r'rna polymerase',
            r'transcription',
            r'transcriptional',
            r'sigma factor'
        ],
        'nucleases': [
            r'nuclease',
            r'endonuclease',
            r'exonuclease'
        ],

        # Host interaction
        'lysis': [
            r'holin',
            r'lysin',
            r'endolysin',
            r'amidase',
            r'peptidase',
            r'lysis',
            r'spanin'
        ],
        'host_manipulation': [
            r'toxin',
            r'antitoxin',
            r'immunity',
            r'infection',
            r'host.*inhibitor',
            r'superinfection',
            r'anti-restriction'
        ],

        # Enzymes
        'transferases': [
            r'transferase',
            r'methyltransferase',
            r'glycosyltransferase'
        ],
        'hydrolases': [
            r'hydrolase',
            r'phosphatase',
            r'phosphohydrolase',
            r'pyrophosphatase'
        ],
        'ligases': [
            r'ligase',
            r'synthetase'
        ],

        # Regulatory proteins
        'regulators': [
            r'regulator',
            r'repressor',
            r'activator',
            r'regulatory',
            r'regulation'
        ],

        # Assembly and morphogenesis
        'morphogenesis': [
            r'scaffolding',
            r'assembly',
            r'morphogenesis',
            r'chaperone'
        ],

        # Other important categories
        'structural': [
            r'structural protein',
            r'virion.*protein'
        ],
        'membrane_associated': [
            r'membrane protein',
            r'membrane associated',
            r'lipoprotein'
        ]
    }


def create_detailed_phage_mapping():
    """
    Creates a detailed dictionary mapping phage proteins to specific functional categories.
    Categories are broken down into fine-grained functional groups.
    """
    return {
        # Head/Capsid components
        'major_capsid': [
            r'major head protein',
            r'major coat protein',
            r'major head and protease protein',
            r'head morphogenesis'
        ],
        'minor_capsid': [
            r'minor head protein',
            r'head decoration',
            r'head fiber protein',
            r'internal head protein'
        ],
        'head_assembly': [
            r'head assembly',
            r'head closure',
            r'prohead',
            r'scaffolding protein',
            r'head maturation'
        ],

        # Tail components
        'major_tail': [
            r'major tail protein',
            r'tail tube protein',
            r'tail sheath'
        ],
        'minor_tail': [
            r'minor tail protein',
            r'tail fiber protein',
            r'tail spike protein',
            r'tail needle protein',
            r'tail tip',
            r'tail associated lysin'
        ],
        'tail_assembly': [
            r'tail assembly',
            r'tail chaperone',
            r'tail assembly chaperone',
            r'tail completion',
            r'tail terminator'
        ],
        'tail_tape_measure': [
            r'tail length tape measure protein',
            r'tape measure'
        ],

        # Connection components
        'portal': [
            r'portal protein'
        ],
        'connector': [
            r'head-tail connector',
            r'head-tail adaptor',
            r'head-tail joining',
            r'neck protein'
        ],
        'baseplate': [
            r'baseplate',
            r'base plate',
            r'baseplate wedge',
            r'baseplate hub'
        ],

        # DNA processing
        'dna_replication': [
            r'dna polymerase',
            r'replication initiation',
            r'replication protein',
            r'dna primase',
            r'helicase',
            r'clamp loader',
            r'single strand.*binding',
            r'ssb'
        ],
        'dna_packaging': [
            r'terminase large subunit',
            r'terminase small subunit',
            r'packaging',
            r'dna packaging'
        ],
        'dna_modification': [
            r'methyltransferase',
            r'dna methyltransferase',
            r'modification protein'
        ],
        'recombination': [
            r'recombinase',
            r'integrase',
            r'excisionase',
            r'resolvase',
            r'invertase',
            r'site-specific recombination'
        ],

        # RNA processing
        'transcription': [
            r'rna polymerase',
            r'sigma factor',
            r'transcription factor'
        ],
        'transcription_regulation': [
            r'transcriptional regulator',
            r'transcriptional activator',
            r'transcriptional repressor',
            r'anti-terminator'
        ],

        # Nucleases
        'endonucleases': [
            r'endonuclease',
            r'restriction endonuclease',
            r'homing endonuclease'
        ],
        'exonucleases': [
            r'exonuclease',
            r'exonuclease V',
            r'exonuclease VIII'
        ],

        # Host interaction
        'lysis': [
            r'holin',
            r'endolysin',
            r'lysin',
            r'spanin',
            r'lysis protein'
        ],
        'peptidases': [
            r'peptidase',
            r'protease',
            r'amidase'
        ],
        'host_takeover': [
            r'host transcription',
            r'host manipulation',
            r'host killing',
            r'host range',
            r'host specificity'
        ],
        'immunity': [
            r'immunity protein',
            r'superinfection',
            r'anti-restriction',
            r'restriction alleviation'
        ],

        # Various enzymes
        'transferases': [
            r'glycosyltransferase',
            r'acetyltransferase',
            r'nucleotidyltransferase',
            r'phosphotransferase',
            r'aminotransferase'
        ],
        'hydrolases': [
            r'hydrolase',
            r'phosphatase',
            r'phosphohydrolase',
            r'pyrophosphatase'
        ],
        'oxidoreductases': [
            r'oxidoreductase',
            r'dehydrogenase',
            r'reductase',
            r'oxidase'
        ],
        'ligases': [
            r'ligase',
            r'synthetase',
            r'dna ligase',
            r'rna ligase'
        ],

        # Membrane and structural
        'membrane_proteins': [
            r'membrane protein',
            r'transmembrane',
            r'lipoprotein'
        ],
        'structural': [
            r'structural protein',
            r'virion structural protein',
            r'virion protein'
        ],

        # Regulatory
        'transcriptional_control': [
            r'repressor',
            r'activator',
            r'regulator'
        ],
        'regulatory_proteins': [
            r'regulatory protein',
            r'regulation',
            r'modulator',
            r'control protein'
        ],

        # Toxin-antitoxin
        'toxin_systems': [
            r'toxin',
            r'antitoxin',
            r'toxin-antitoxin'
        ]
    }

def classify_phage_protein(product_name, categories):
    """
    Classifies a phage protein name into detailed categories.

    Parameters:
    product_name (str): Original protein product name
    categories (dict): Dictionary of category patterns

    Returns:
    str or np.nan: Category name or np.nan if no match found
    """
    if pd.isna(product_name):
        return pd.NA

    product_name = str(product_name).lower()

    for category, patterns in categories.items():
        if any(re.search(pattern.lower(), product_name) for pattern in patterns):
            return category

    return pd.NA

def map_phage_proteins(df, product_column):
    """
    Maps phage proteins in a DataFrame to detailed functional categories.

    Parameters:
    df (pandas.DataFrame): DataFrame containing protein information
    product_column (str): Name of the column containing protein product names

    Returns:
    pandas.DataFrame: Original DataFrame with new 'product_category' column
    """
    categories = create_detailed_phage_mapping()
    df = df.copy()

    df['product_category'] = df[product_column].apply(
        lambda x: classify_phage_protein(x, categories)
    )

    return df

df_new = map_phage_proteins(df, "product")
df_new["product_category"].unique()
# Out:
# array(['connector', 'transcription_regulation', 'lysis', 'minor_capsid',
#        'endonucleases', 'major_tail', <NA>, 'tail_tape_measure',
#        'dna_replication', 'minor_tail', 'major_capsid', 'recombination',
#        'dna_modification', 'transferases', 'oxidoreductases',
#        'structural', 'tail_assembly', 'dna_packaging', 'head_assembly',
#        'transcription', 'transcriptional_control', 'toxin_systems',
#        'portal', 'baseplate', 'membrane_proteins', 'ligases',
#        'exonucleases', 'immunity', 'peptidases', 'hydrolases',
#        'host_takeover', 'regulatory_proteins'], dtype=object)

# %%
df_new.to_csv("processed/foldseek_new2.csv", index=False)
